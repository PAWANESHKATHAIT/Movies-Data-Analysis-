# %% [markdown]
# ## Extract Data

# %%
import pandas as pd

# %%
import time
data_list1 = []

def fetch_data(movie_id):
    try:
        response = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}?api_key=612cdb5b1e5464fd7d3651fa166e54ee', timeout=10)
        response.raise_for_status()  # Will raise HTTPError for bad responses (4xx and 5xx)
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Request failed for movie ID {movie_id}: {e}")
        return None

# Fetch data for movie IDs
for j in range(1, 14000):
    temp_data1 = fetch_data(j)
    if temp_data1:
        data_list1.append(temp_data1)
    time.sleep(0.5)  # Adding a delay to prevent hitting API rate limits

# Convert the data to a DataFrame
df3 = pd.DataFrame(data_list1)
# Out:
# Request failed for movie ID 1: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/1?api_key=612cdb5b1e5464fd7d3651fa166e54ee
# Request failed for movie ID 4: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/4?api_key=612cdb5b1e5464fd7d3651fa166e54ee
# Request failed for movie ID 7: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/7?api_key=612cdb5b1e5464fd7d3651fa166e54ee
# Request failed for movie ID 10: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/10?api_key=612cdb5b1e5464fd7d3651fa166e54ee
# Request failed for movie ID 23: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/23?api_key=612cdb5b1e5464fd7d3651fa166e54ee
# Request failed for movie ID 29: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/29?api_key=612cdb5b1e5464fd7d3651fa166e54ee
# ...

# %%
# Display the DataFrame
df3.head(2)
# Out:
#    adult                     backdrop_path belongs_to_collection  budget  \
# 0  False  /hQ4pYsIbP22TMXOUdSfC2mjWrO0.jpg                  None       0
# 1  False  /l94l89eMmFKh7na2a1u5q67VgNx.jpg                  None       0
#
#                                               genres homepage  id    imdb_id  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...            2  tt0094675
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...            3  tt0092149
#
#   origin_country original_language  ... release_date revenue  runtime  \
# 0           [FI]                fi  ...   1988-10-21       0       73
# 1           [FI]                fi  ...   1986-10-17       0       74
#
#                                     spoken_languages    status tagline  \
# 0  [{'english_name': 'Finnish', 'iso_639_1': 'fi'...  Released
# 1  [{'english_name': 'Finnish', 'iso_639_1': 'fi'...  Released
#
#                  title  video  vote_average vote_count
# ...

# %%
df3.to_csv("Movies_details.csv")
